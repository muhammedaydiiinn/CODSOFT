row0_col5" class="data row0 col5" >10000.000000</td>
#       <td id="T_f33bd_row0_col6" class="data row0 col6" >10000.000000</td>
#       <td id="T_f33bd_row0_col7" class="data row0 col7" >10000.000000</td>
#       <td id="T_f33bd_row0_col8" class="data row0 col8" >10000.000000</td>
#       <td id="T_f33bd_row0_col9" class="data row0 col9" >10000.000000</td>
#       <td id="T_f33bd_row0_col10" class="data row0 col10" >10000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f33bd_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_f33bd_row1_col0" class="data row1 col0" >5000.500000</td>
#       <td id="T_f33bd_row1_col1" class="data row1 col1" >15690940.569400</td>
#       <td id="T_f33bd_row1_col2" class="data row1 col2" >650.528800</td>
#       <td id="T_f33bd_row1_col3" class="data row1 col3" >38.921800</td>
#       <td id="T_f33bd_row1_col4" class="data row1 col4" >5.012800</td>
#       <td id="T_f33bd_row1_col5" class="data row1 col5" >76485.889288</td>
#       <td id="T_f33bd_row1_col6" class="data row1 col6" >1.530200</td>
#       <td id="T_f33bd_row1_col7" class="data row1 col7" >0.705500</td>
#       <td id="T_f33bd_row1_col8" class="data row1 col8" >0.515100</td>
#       <td id="T_f33bd_row1_col9" class="data row1 col9" >100090.239881</td>
#       <td id="T_f33bd_row1_col10" class="data row1 col10" >0.203700</td>
#     </tr>
#     <tr>
#       <th id="T_f33bd_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_f33bd_row2_col0" class="data row2 col0" >2886.895680</td>
#       <td id="T_f33bd_row2_col1" class="data row2 col1" >71936.186123</td>
#       <td id="T_f33bd_row2_col2" class="data row2 col2" >96.653299</td>
#       <td id="T_f33bd_row2_col3" class="data row2 col3" >10.487806</td>
#       <td id="T_f33bd_row2_col4" class="data row2 col4" >2.892174</td>
#       <td id="T_f33bd_row2_col5" class="data row2 col5" >62397.405202</td>
#       <td id="T_f33bd_row2_col6" class="data row2 col6" >0.581654</td>
#       <td id="T_f33bd_row2_col7" class="data row2 col7" >0.455840</td>
#       <td id="T_f33bd_row2_col8" class="data row2 col8" >0.499797</td>
#       <td id="T_f33bd_row2_col9" class="data row2 col9" >57510.492818</td>
#       <td id="T_f33bd_row2_col10" class="data row2 col10" >0.402769</td>
#     </tr>
#     <tr>
#       <th id="T_f33bd_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_f33bd_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_f33bd_row3_col1" class="data row3 col1" >15565701.000000</td>
#       <td id="T_f33bd_row3_col2" class="data row3 col2" >350.000000</td>
#       <td id="T_f33bd_row3_col3" class="data row3 col3" >18.000000</td>
#       <td id="T_f33bd_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_f33bd_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_f33bd_row3_col6" class="data row3 col6" >1.000000</td>
#       <td id="T_f33bd_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_f33bd_row3_col8" class="data row3 col8" >0.000000</td>
#       <td id="T_f33bd_row3_col9" class="data row3 col9" >11.580000</td>
#       <td id="T_f33bd_row3_col10" class="data row3 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f33bd_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_f33bd_row4_col0" class="data row4 col0" >2500.750000</td>
#       <td id="T_f33bd_row4_col1" class="data row4 col1" >15628528.250000</td>
#       <td id="T_f33bd_row4_col2" class="data row4 col2" >584.000000</td>
#       <td id="T_f33bd_row4_col3" class="d

# %%
df.drop(columns = ['CustomerId','Surname','RowNumber'],inplace=True)

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Exited',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='Exited', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Geography        10000 non-null  object
#  2   Gender           10000 non-null  object
#  3   Age              10000 non-null  int64
#  4   Tenure           10000 non-null  int64
#  5   Balance          10000 non-null  float64
#  6   NumOfProducts    10000 non-null  int64
#  7   HasCrCard        10000 non-null  int64
#  8   IsActiveMember   10000 non-null  int64
#  9   EstimatedSalary  10000 non-null  float64
#  10  Exited           10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 859.5+ KB

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
fig=plt.figure(figsize=(10,4))
ax=[None for _ in range(2)]
ax[0]=plt.subplot2grid((1,2),(0,0))
ax[1]=plt.subplot2grid((1,2),(0,1))

sns.countplot(x='Geography',data=df,palette='rainbow',ax=ax[0])
sns.countplot(x='Gender',data=df,palette='rainbow',ax=ax[1])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df = pd.get_dummies(df,columns=['Geography','Gender'],drop_first=True)

# %%
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1              False
# 1               1        112542.58       0              False
# 2               0        113931.57       1              False
# 3               0         93826.63       0              False
# 4               1         79084.10       0              False
#
#    Geography_Spain  Gender_Male
# 0            False        False
# 1             True        False
# 2            False        False
# 3            False        False
# 4             True        False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CreditScore        10000 non-null  int64
#  1   Age                10000 non-null  int64
#  2   Tenure             10000 non-null  int64
#  3   Balance            10000 non-null  float64
#  4   NumOfProducts      10000 non-null  int64
#  5   HasCrCard          10000 non-null  int64
#  6   IsActiveMember     10000 non-null  int64
#  7   EstimatedSalary    10000 non-null  float64
#  8   Exited             10000 non-null  int64
#  9   Geography_Germany  10000 non-null  bool
#  10  Geography_Spain    10000 non-null  bool
#  11  Gender_Male        10000 non-null  bool
# dtypes: bool(3), float64(2), int64(7)
# memory usage: 732.6 KB

# %%
numerical_features=[feature for feature in df.columns if df[feature].dtype!='object']
df_num=df[numerical_features]

# %%
plt.figure(figsize=(10,8))
corr=df_num.corr()
sns.heatmap(corr,cmap=plt.cm.RdBu_r,annot=True,annot_kws={'size':10})
# Out:
# <Axes: >

# %%
num_features = len(numerical_features)
rows = num_features // 2 + num_features % 2  # Calculate the number of rows needed based on the features

fig, ax = plt.subplots(nrows=rows, ncols=2, figsize=(14, rows * 4))  # Adjust grid size dynamically
i = 0
for feature in numerical_features:
    n = i // 2
    m = i % 2
    sns.kdeplot(x=feature, data=df, ax=ax[n, m])
    i += 1

# %%
X = df.drop(columns=['Exited'])
y = df['Exited']

# %%
X.shape
# Out:
# (10000, 11)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.shape
# Out:
# (8000, 11)

# %%
from sklearn.ensemble import RandomForestClassifier,VotingClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score


#random forest
forest=RandomForestClassifier()
param_grid = { 
    'n_estimators': [100,200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}
grid_search=RandomizedSearchCV(estimator=forest,param_distributions=param_grid,cv=3,scoring='roc_auc',n_iter=10,verbose=True)

# %%
grid_search.fit(X,y)
rf_pred = grid_search.predict(X_test)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

forest=grid_search.best_estimator_
scores_forest=cross_val_score(forest,X,y,cv=5)
print("\nRandom Forest:")
print("Accuracy:", accuracy_score(y_test, rf_pred))
print("Classification Report:\n", classification_report(y_test, rf_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, rf_pred))
# Out:
# Random Forest:
# Accuracy: 0.8895
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      1595
#            1       0.89      0.52      0.65       405
#
#     accuracy                           0.89      2000
#    macro avg       0.89      0.75      0.79      2000
# weighted avg       0.89      0.89      0.88      2000
#
# Confusion Matrix:
#  [[1570   25]
#  [ 196  209]]

# %%
# GradientBoosting

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Initialize Gradient Boosting Classifier
gb_clf = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=0)

# Train the model
gb_clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = gb_clf.predict(X_test)

# Assess model performance
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")

conf_matrix = confusion_matrix(y_test, y_pred)
print(f"Confusion Matrix:\n{conf_matrix}")

class_report = classification_report(y_test, y_pred)
print(f"Classification Report:\n{class_report}")
# Out:
# Accuracy: 0.8670
# Confusion Matrix:
# [[1523   72]
#  [ 194  211]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      1595
#            1       0.75      0.52      0.61       405
#
#     accuracy                           0.87      2000
#    macro avg       0.82      0.74      0.77      2000
# weighted avg       0.86      0.87      0.86      2000

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression


lr_model = LogisticRegression()
lr_model.fit(X_train, y_train)

# Random Forest
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Gradient Boosting
gb_model = GradientBoostingClassifier(n_estimators=100, random_state=42)
gb_model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
lr_pred = lr_model.predict(X_test)

# Evaluate model performance
print("Logistic Regression:")
print("Accuracy:", accuracy_score(y_test, lr_pred))
print("Classification Report:\n", classification_report(y_test, lr_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, lr_pred))
# Out:
# Logistic Regression:
# Accuracy: 0.789
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.97      0.88      1595
#            1       0.37      0.06      0.11       405
#
#     accuracy                           0.79      2000
#    macro avg       0.59      0.52      0.49      2000
# weighted avg       0.72      0.79      0.72      2000
#
# Confusion Matrix:
#  [[1553   42]
#  [ 380   25]]

# %%
# Boxplot for Age and CreditScore
plt.figure(figsize=(12, 6))
sns.boxplot(x='Exited', y='Age', data=df, palette='Set2')
plt.title('Boxplot of Age by Churn')
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(x='Exited', y='CreditScore', data=df, palette='Set2')
plt.title('Boxplot of CreditScore by Churn')
plt.show()
